# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\hou_all.csv")

# %%
df
# Out:
#      0.00632   18   2.31  0  0.538  6.575  65.2    4.09  1  296  15.3   396.9  \
# 0    0.02731  0.0   7.07  0  0.469  6.421  78.9  4.9671  2  242  17.8  396.90
# 1    0.02729  0.0   7.07  0  0.469  7.185  61.1  4.9671  2  242  17.8  392.83
# 2    0.03237  0.0   2.18  0  0.458  6.998  45.8  6.0622  3  222  18.7  394.63
# 3    0.06905  0.0   2.18  0  0.458  7.147  54.2  6.0622  3  222  18.7  396.90
# 4    0.02985  0.0   2.18  0  0.458  6.430  58.7  6.0622  3  222  18.7  394.12
# ..       ...  ...    ... ..    ...    ...   ...     ... ..  ...   ...     ...
# 500  0.06263  0.0  11.93  0  0.573  6.593  69.1  2.4786  1  273  21.0  391.99
# 501  0.04527  0.0  11.93  0  0.573  6.120  76.7  2.2875  1  273  21.0  396.90
# 502  0.06076  0.0  11.93  0  0.573  6.976  91.0  2.1675  1  273  21.0  396.90
# 503  0.10959  0.0  11.93  0  0.573  6.794  89.3  2.3889  1  273  21.0  393.45
# 504  0.04741  0.0  11.93  0  0.573  6.030  80.8  2.5050  1  273  21.0  396.90
#
#      4.98    24  1.1
# ...

# %%
df.columns
# Out:
# Index(['0.00632', '18', '2.31', '0', '0.538', '6.575', '65.2', '4.09', '1',
#        '296', '15.3', '396.9', '4.98', '24', '1.1'],
#       dtype='object')

# %%
df.rename({"0.00632":"CRIM" , "18":"ZN","2.31":"INDUS","0":"CHAS","0.538":"NOX","6.575":"RM","65.2"
:"AGE","4.09":"DIS","1":"RAD","296":"TAX","15.3":"PTRATIO","396.9":"BLACK","4.98":"LSTAT","24":"MEDV"} ,axis = "columns", inplace = True)

# %%
df
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 1    0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 2    0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3    0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4    0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 500  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 501  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 502  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 503  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 504  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       BLACK  LSTAT  MEDV  1.1
# ...

# %%
name = x.columns
name
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'BLACK', 'LSTAT'],
#       dtype='object')

# %%
rng = range(len(name))

# %%
y = df['MEDV']

# %%
y.name
# Out:
# 'MEDV'

# %%
x = df.drop("MEDV" , axis = 1)

# %%
x.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'BLACK', 'LSTAT'],
#       dtype='object')

# %%
from sklearn.linear_model import Lasso
ls = Lasso(alpha=0.1)
ls
rng = range(len(cf))

# %%
data = ls.fit(x,y)

# %%
cf = data.coef_
cf
# Out:
# array([-0.09730677,  0.04885528, -0.04306841,  0.94196291, -0.        ,
#         3.6848137 , -0.00948122, -1.16688466,  0.26999458, -0.01424252,
#        -0.77916383,  0.0102343 , -0.5717614 ])

# %%
# 5th columns has the highest value hence it will have the highest level and highest influence
ls.fit(x, y)
# Out:
# Lasso(alpha=0.1)

# %%
plt.figure(figsize=(10,5))
plt.bar(x.columns, cf)
plt.xticks(rotation=60)
plt.ylabel("Coefficient")
plt.show()

# %%
newdata = [[0.00632	,18,2.31,0,0.538,	65.2,4.09,1,296,15.3,396.9,4.98,24]]

# %%
price = data.predict(newdata)
price
# Out:
# C:\Users\DELL\OneDrive\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# array([22.48078969])
