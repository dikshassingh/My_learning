# %%
import pandas as pd
import matplotlib
import seaborn

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\Anaconda\Dikshaprj\archive\car_data.csv")

# %%
print(df.shape)
# Out:
# (42089, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42089 entries, 0 to 42088
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           42089 non-null  int64
#  1   car_brand            42089 non-null  object
#  2   car_model            42089 non-null  object
#  3   car_price            42089 non-null  int64
#  4   car_city             42089 non-null  object
#  5   car_fuel             42089 non-null  object
#  6   car_transmission     42089 non-null  object
#  7   car_drive            42089 non-null  object
#  8   car_mileage          42089 non-null  int64
#  9   car_country          42089 non-null  object
#  10  car_engine_capacity  42089 non-null  float64
#  11  car_engine_hp        42089 non-null  int64
#  12  car_age              42089 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 4.2+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_brand', 'car_model', 'car_price', 'car_city',
#        'car_fuel', 'car_transmission', 'car_drive', 'car_mileage',
#        'car_country', 'car_engine_capacity', 'car_engine_hp', 'car_age'],
#       dtype='object')

# %%
df.columns.values
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'car_brand',
#  'car_model',
#  'car_price',
#  'car_city',
#  'car_fuel',
#  'car_transmission',
#  'car_drive',
#  'car_mileage',
#  'car_country',
#  'car_engine_capacity',
#  'car_engine_hp',
#  'car_age']

# %%
df.head()
# Out:
#    Unnamed: 0      car_brand      car_model  car_price   car_city  car_fuel  \
# 0           0           Ford      Focus         550000  Astrakhan  gasoline
# 1           1  Mercedes-Benz  GLA-Class        1820000  Astrakhan  gasoline
# 2           2          Haval         F7        2600000  Astrakhan  gasoline
# 3           3         Toyota      Camry        4200000  Astrakhan  gasoline
# 4           4          OMODA         C5        2125000  Astrakhan  gasoline
#
#   car_transmission car_drive  car_mileage car_country  car_engine_capacity  \
# 0           manual       FWD       300000         USA                  1.8
# 1            robot       FWD        88000          DE                  1.6
# 2            robot       4WD        19000          CN                  1.5
# 3        automatic       FWD        30000          JP                  3.5
# 4              CVT       FWD        18824          CN                  1.5
#
#    car_engine_hp  car_age
# 0            125       14
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0      car_brand         car_model  car_price   car_city  \
# 0           0           Ford         Focus         550000  Astrakhan
# 1           1  Mercedes-Benz     GLA-Class        1820000  Astrakhan
# 2           2          Haval            F7        2600000  Astrakhan
# 3           3         Toyota         Camry        4200000  Astrakhan
# 4           4          OMODA            C5        2125000  Astrakhan
# 5           5  Mercedes-Benz       E-Class        3779999  Astrakhan
# 6           6         Toyota          RAV4        2539000  Astrakhan
# 7           7           Ford         Focus         555000  Astrakhan
# 8           8          Honda         Civic         455000  Astrakhan
# 9           9            Kia  Rio X (X-Line)      1950000  Astrakhan
#
#    car_fuel car_transmission car_drive  car_mileage car_country  \
# 0  gasoline           manual       FWD       300000         USA
# 1  gasoline            robot       FWD        88000          DE
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0 car_brand        car_model  car_price car_city  car_fuel  \
# 42084       42084     Isuzu      Bighorn         450000  Yakutsk    diesel
# 42085       42085    Toyota  Corolla Axio        650000  Yakutsk  gasoline
# 42086       42086  Daihatsu        Be-Go        1350000  Yakutsk  gasoline
# 42087       42087     Mazda      Tribute         550000  Yakutsk  gasoline
# 42088       42088     Lexus        GX460        4000000  Yakutsk  gasoline
#
#       car_transmission car_drive  car_mileage car_country  \
# 42084        automatic       4WD       183212          JP
# 42085              CVT       FWD       110000          JP
# 42086        automatic       4WD       153000          JP
# 42087        automatic       4WD       190000          JP
# 42088        automatic       4WD       217000          JP
#
#        car_engine_capacity  car_engine_hp  car_age
# 42084                  3.1            125       30
# 42085                  1.5            110       13
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0 car_brand        car_model  car_price car_city  car_fuel  \
# 42079       42079     Honda         Logo         150000  Yakutsk  gasoline
# 42080       42080    Daewoo        Nexia         730000  Yakutsk  gasoline
# 42081       42081    Toyota       Probox        1250000  Yakutsk  gasoline
# 42082       42082    Nissan      Presage         550000  Yakutsk  gasoline
# 42083       42083    Toyota         Noah        2100000  Yakutsk    hybrid
# 42084       42084     Isuzu      Bighorn         450000  Yakutsk    diesel
# 42085       42085    Toyota  Corolla Axio        650000  Yakutsk  gasoline
# 42086       42086  Daihatsu        Be-Go        1350000  Yakutsk  gasoline
# 42087       42087     Mazda      Tribute         550000  Yakutsk  gasoline
# 42088       42088     Lexus        GX460        4000000  Yakutsk  gasoline
#
#       car_transmission car_drive  car_mileage car_country  \
# 42079        automatic       FWD       200000          JP
# ...

# %%
dd = df.drop_duplicates(keep='first')

# %%
dd
# Out:
#        Unnamed: 0      car_brand        car_model  car_price   car_city  \
# 0               0           Ford        Focus         550000  Astrakhan
# 1               1  Mercedes-Benz    GLA-Class        1820000  Astrakhan
# 2               2          Haval           F7        2600000  Astrakhan
# 3               3         Toyota        Camry        4200000  Astrakhan
# 4               4          OMODA           C5        2125000  Astrakhan
# ...           ...            ...              ...        ...        ...
# 42084       42084          Isuzu      Bighorn         450000    Yakutsk
# 42085       42085         Toyota  Corolla Axio        650000    Yakutsk
# 42086       42086       Daihatsu        Be-Go        1350000    Yakutsk
# 42087       42087          Mazda      Tribute         550000    Yakutsk
# 42088       42088          Lexus        GX460        4000000    Yakutsk
#
#        car_fuel car_transmission car_drive  car_mileage car_country  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# car_brand              0
# car_model              0
# car_price              0
# car_city               0
# car_fuel               0
# car_transmission       0
# car_drive              0
# car_mileage            0
# car_country            0
# car_engine_capacity    0
# car_engine_hp          0
# car_age                0
# dtype: int64

# %%
df.sort_values(by='car_price',ascending=False)
# Out:
#        Unnamed: 0      car_brand         car_model  car_price  \
# 16651       16651    Rolls-Royce       Phantom       69999999
# 16654       16654  Mercedes-Benz       G-Class       69999999
# 16645       16645    Rolls-Royce       Phantom       67800000
# 16646       16646        Ferrari  SF90 Stradale      59999999
# 16644       16644  Mercedes-Benz       G-Class       55999999
# ...           ...            ...               ...        ...
# 7534         7534           Lada         21099          35000
# 6132         6132           Lada          2107          30000
# 976           976            ZAZ   Zaporozhets          30000
# 37863       37863           ЛуАЗ          ЛуАЗ          30000
# 10757       10757            Kia          Soul           7000
#
#               car_city  car_fuel car_transmission car_drive  car_mileage  \
# 16651           Moscow  gasoline        automatic       RWD         6500
# ...

# %%
df['car_country'].unique()
# Out:
# array(['USA', 'DE', 'CN', 'JP', 'KR', 'FR', 'RUS', 'CZ', 'UK', 'UZ',
#        'KR ', 'SE', 'ES', 'IT', 'IR', 'UKR'], dtype=object)

# %%
def origin_to_num(x):
    if x == "USA" : return 1
    if x == "DE" : return 2
    if x == "CN" : return 3

# %%
df.iloc[0]
# Out:
# Unnamed: 0                     0
# car_brand                   Ford
# car_model              Focus
# car_price                 550000
# car_city               Astrakhan
# car_fuel                gasoline
# car_transmission          manual
# car_drive                    FWD
# car_mileage               300000
# car_country                  USA
# car_engine_capacity          1.8
# car_engine_hp                125
# car_age                       14
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    Unnamed: 0      car_brand      car_model  car_price   car_city  car_fuel  \
# 0           0           Ford      Focus         550000  Astrakhan  gasoline
# 1           1  Mercedes-Benz  GLA-Class        1820000  Astrakhan  gasoline
# 2           2          Haval         F7        2600000  Astrakhan  gasoline
# 3           3         Toyota      Camry        4200000  Astrakhan  gasoline
# 4           4          OMODA         C5        2125000  Astrakhan  gasoline
#
#   car_transmission car_drive  car_mileage car_country  car_engine_capacity  \
# 0           manual       FWD       300000         USA                  1.8
# 1            robot       FWD        88000          DE                  1.6
# 2            robot       4WD        19000          CN                  1.5
# 3        automatic       FWD        30000          JP                  3.5
# 4              CVT       FWD        18824          CN                  1.5
#
#    car_engine_hp  car_age
# 0            125       14
# ...

# %%
df.iloc[-1]
# Out:
# Unnamed: 0                 42088
# car_brand                  Lexus
# car_model              GX460
# car_price                4000000
# car_city                 Yakutsk
# car_fuel                gasoline
# car_transmission       automatic
# car_drive                    4WD
# car_mileage               217000
# car_country                   JP
# car_engine_capacity          4.6
# car_engine_hp                296
# car_age                       13
# Name: 42088, dtype: object

# %%
df.iloc[1:,4:]
# Out:
#         car_city  car_fuel car_transmission car_drive  car_mileage  \
# 1      Astrakhan  gasoline            robot       FWD        88000
# 2      Astrakhan  gasoline            robot       4WD        19000
# 3      Astrakhan  gasoline        automatic       FWD        30000
# 4      Astrakhan  gasoline              CVT       FWD        18824
# 5      Astrakhan  gasoline        automatic       4WD       125000
# ...          ...       ...              ...       ...          ...
# 42084    Yakutsk    diesel        automatic       4WD       183212
# 42085    Yakutsk  gasoline              CVT       FWD       110000
# 42086    Yakutsk  gasoline        automatic       4WD       153000
# 42087    Yakutsk  gasoline        automatic       4WD       190000
# 42088    Yakutsk  gasoline        automatic       4WD       217000
#
#       car_country  car_engine_capacity  car_engine_hp  car_age
# 1              DE                  1.6            156       10
# ...

# %%
df
